# %%
# !pip install plotly

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

sns.set(style='whitegrid')
plt.rcParams['figure.figsize'] = (10, 6)

df = sns.load_dataset("titanic")
df.head()

df.dropna(subset=['age', 'fare', 'embarked'], inplace=True)  # Example cleaning
df.reset_index(drop=True, inplace=True)

sns.countplot(x='sex', hue='survived', data=df)
plt.title('Survival Count by Gender')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.legend(title='Survived', labels=['No', 'Yes'])
plt.show()

corr = df[['age', 'fare', 'pclass']].corr()
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

fig = px.scatter(df, x='age', y='fare', color='pclass',
                 size='fare', hover_data=['sex', 'survived'],
                 title='Fare vs Age by Class (Interactive)')
fig.show()

print("🔍 Inference:")
print("- Females had a significantly higher survival rate than males.")
print("- Fare is negatively correlated with passenger class, suggesting higher prices for better classes.")
print("- The scatter plot highlights how younger passengers vary in fare across classes.")
# Out:
# Requirement already satisfied: plotly in /usr/local/lib/python3.11/dist-packages (5.24.1)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from plotly) (9.1.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from plotly) (24.2)
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="63ce8869-bbc1-4bad-9a60-02927c141863" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("63ce8869-bbc1-4bad-9a60-02927c141863")) {                    Plotly.newPlot(                        "63ce8869-bbc1-4bad-9a60-02927c141863",                        [{"customdata":[["male",0],["female",1],["female",1],["female",1],["male",0],["male",0],["male",0],["female",1],["female",1],["female",1],["female",1],["male",0],["male",0],["female",0],["female",1],["male",0],["female",0],["male",0],["male",1],["female",1],["male",1],["female",0],["female",1],["male",0],["male",0],["male",0],["male",0],["male",0],["male",0],["female",0],["female",1],["female",0],["female",0],["female",1],["female",1],["female",0],["male",0],["male",0],["female",1],["female",1],["male",0],["female",1],["male",0],["female",1],["male",0],["male",0],["male",0],["male",0],["female",1],["male",0],["female",1],["male",0],["male",0],["female",0],["male",0],["male",0],["male",1],["male",0],["male",1],["female",1],["male",0],["male",1],["male",0],["female",1],["female",1],["male",0],["female",1],["male",0],["male",0],["male",0],["male",0],["male",0],["male",0],["male",0],["male",1],["female",1],["male",0],["female",0],["male",0],["male",0],["male",0],["male",0],["female",1],["male",0],["male",0],["female",0],["male",0],["female",0],["female",0],["male",0],["male",0],["male",0],["male",0],["female",0],["male",0],["male",0],["female",1],["male",0],["male",1],["male",1],["male",0],["male",0],["male",0],["female",0],["female",1],["male",0],["male",0],["female",1],["male",0],["male",0],["male",0],["female",1],["female",1],["male",0],["male",0],["male",0],["male",1],["female",0],["male",0],["male",0],["male",0],["female",1],["male",0],["male",0],["male",0],["female",1],["male",0],["male",0],["female",1],["male",0],["male",0],["male",0],["male",1],["female",0],["male",0],["male",0],["male",0],["female",1],["male",0],["male",0],["male",0],["female",0],["male",0],["male",0],["male",0],["male",1],["female",1],["male",1],["male",0],["male",0],["female",1],["male",0],["female",1],["male",1],["female",1],["female",1],["male",0],["female",0],["male",0],["male",0],["male",0],["male",1],["female",0],["male",0],["male",1],["female",1],["male",1],["male",0],["female",1],["male",0],["male",0],["female",1],["female",1],["male",0],["female",1],["male",0],["male",1],["male",0],["male",0],["male",1],["male",0],["male",1],["male",0],["male",0],["female",1],["male",0],["male",0],["female",1],["male",0],["male",0],["female",1],["male",0],["male",0],["male",0],["male",0],["male",0],["male",0],["female",0],["female",1],["male",1],["male",0],["female",0],["male",0],["male",0],["female",0],["female",1],["female",1],["female",1],["female",1],["male",1],["male",0],["male",0],["male",0],["male",0],["male",1],["female",1],["female",1],["male",1],["female",1],["male",0],["female",1],["female",0],["male",0],["female",1],["male",0],["male",0],["male",0],["male",1],["male",0],["male",1],["male",0],["male",1],["female",1],["female",1],["female",1],["male",0],["female",0],["male",0],["male",0],["female",0],["female",1],["male",0],["male",1],["female",1],["male",0],["female",1],["female",1],["female",1],["female",0],["male",0],["male",0],["female",1],["female",1],["male",0],["female",1],["female",1],["male",0],["male",0],["female",1],["female",1],["female",1],["male",0],["female",1],["female",1],["female",1],["male",0],["male",0],["male",0],["male",0],["female",1],["male",1],["male",0],["male",1],["female",1],["male",0],["male",0],["male",0],["female",1],["female",1],["male",1],["male",0],["male",0],["male",0],["male",0],["male",0],["female",1],["female",0],["male",0],["male",0],["female",0],["male",0],["ma ...
# 🔍 Inference:
# - Females had a significantly higher survival rate than males.
# - Fare is negatively correlated with passenger class, suggesting higher prices for better classes.
# - The scatter plot highlights how younger passengers vary in fare across classes.
